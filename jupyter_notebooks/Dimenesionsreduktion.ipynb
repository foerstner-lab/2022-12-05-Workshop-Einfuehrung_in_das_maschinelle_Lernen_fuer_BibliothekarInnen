# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
from sklearn.decomposition import PCA
pca = PCA(random_state=1, n_components=2)

# %%
pca_result = pca.fit_transform(digits.data)

# %%
pca_result.shape
# Out:
# (1797, 2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=digits.target, cmap="Set1")
plt.colorbar()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=1, n_components=2)
tsne_result = tsne.fit_transform(digits.data)
# Out:
# /nix/store/l09wiykpchsjwwwrc5pd0ksk247pkiz3-python3.9-scikit-learn-1.0.2/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /nix/store/l09wiykpchsjwwwrc5pd0ksk247pkiz3-python3.9-scikit-learn-1.0.2/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
fig, ax = plt.subplots()
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=digits.target, cmap="Set1")
plt.colorbar()
